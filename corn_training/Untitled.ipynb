# %%
import pandas as pd
import numpy as np

# %%
df=pd.read_csv(r'/home/23ucs747/mini-project-sem5/selected_low_confidence.csv')
df.head(10)
# Out:
#                                           image_path true_label  \
# 0  /home/23ucs747/mini-project-sem5/dataset_split...     Blight
# 1  /home/23ucs747/mini-project-sem5/dataset_split...     Blight
# 2  /home/23ucs747/mini-project-sem5/dataset_split...     Blight
# 3  /home/23ucs747/mini-project-sem5/dataset_split...     Blight
# 4  /home/23ucs747/mini-project-sem5/dataset_split...     Blight
# 5  /home/23ucs747/mini-project-sem5/dataset_split...     Blight
# 6  /home/23ucs747/mini-project-sem5/dataset_split...     Blight
# 7  /home/23ucs747/mini-project-sem5/dataset_split...     Blight
# 8  /home/23ucs747/mini-project-sem5/dataset_split...     Blight
# 9  /home/23ucs747/mini-project-sem5/dataset_split...     Blight
#
#        pred_label  confidence
# 0          Blight    0.667874
# 1  Gray_Leaf_Spot    0.650124
# 2          Blight    0.629605
# 3  Gray_Leaf_Spot    0.651194
# 4          Blight    0.557675
# 5          Blight    0.584602
# 6          Blight    0.651058
# ...

# %%
df['confidence'].mean()
# Out:
# np.float64(0.5824578236637077)

# %%
df1=pd.read_csv('/home/23ucs747/mini-project-sem5/predictions_corn_v1.csv')

# %%
df1.head(10)
# Out:
#                                           image_path true_label  \
# 0  /home/23ucs747/mini-project-sem5/dataset_split...     Blight
# 1  /home/23ucs747/mini-project-sem5/dataset_split...     Blight
# 2  /home/23ucs747/mini-project-sem5/dataset_split...     Blight
# 3  /home/23ucs747/mini-project-sem5/dataset_split...     Blight
# 4  /home/23ucs747/mini-project-sem5/dataset_split...     Blight
# 5  /home/23ucs747/mini-project-sem5/dataset_split...     Blight
# 6  /home/23ucs747/mini-project-sem5/dataset_split...     Blight
# 7  /home/23ucs747/mini-project-sem5/dataset_split...     Blight
# 8  /home/23ucs747/mini-project-sem5/dataset_split...     Blight
# 9  /home/23ucs747/mini-project-sem5/dataset_split...     Blight
#
#        pred_label  confidence
# 0          Blight    0.954561
# 1          Blight    0.712725
# 2          Blight    0.831844
# 3          Blight    0.667874
# 4          Blight    0.888056
# 5  Gray_Leaf_Spot    0.798714
# 6  Gray_Leaf_Spot    0.650124
# ...

# %%
df1['confidence'].mean()
# Out:
# np.float64(0.9095499299132153)

# %%
df1['confidence'].min()
# Out:
# np.float64(0.3028009831905365)

# %%
df['confidence'].min()
# Out:
# np.float64(0.3028009831905365)
